# %%
test_dem = r'C:\Users\ZOZN109\OneDrive - Universitetet i Oslo\xsnow\2022-03-11_HardangerL1_North_raster_1m.tif'

# %%
import xdem
xdem.DEM(test_dem)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 import xdem
# ----> 2 xdem.DEM(test_dem)
#
# File c:\Users\ZOZN109\Documents\GitHub\xdem_snow\xdem\dem.py:88, in DEM.__init__(self, filename_or_dataset, vref_name, vref_grid, silent, **kwargs)
#      86 # self.indexes can be None when data is not loaded through the Raster class
#      87 if self.indexes is not None and len(self.indexes) > 1:
# ---> 88     raise ValueError("DEM rasters should be composed of one band only")
#      90 # user input
#      91 self.vref = vref_name
#
# ValueError: DEM rasters should be composed of one band only

# %%
xdem.DEM(test_dem,indexes=3)
# Out:
# Driver:               GTiff
# Opened from file:     C:\Users\ZOZN109\OneDrive - Universitetet i Oslo\xsnow\2022-03-11_HardangerL1_North_raster_1m.tif
# Filename:             C:/Users/ZOZN109/OneDrive - Universitetet i Oslo/xsnow/2022-03-11_HardangerL1_North_raster_1m.tif
# Raster modified since disk load?  False
# Size:                 522, 1908
# Number of bands:      1
# Data types:           ('float64',)
# Coordinate System:    ['EPSG:25832']
# NoData Value:         -9999.0
# Pixel Size:           1.0, 1.0
# Upper Left Corner:    429029.57106480515, 6699105.160347686
# Lower Right Corner:   429551.57106480515, 6701013.160347686

# %%
! pip list
# Out:
# Package                       Version     Editable project location
# ----------------------------- ----------- -------------------------------------------
# affine                        2.3.1
# alabaster                     0.7.13
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.2.1
# attrs                         22.2.0
# autovizwidget                 0.20.3
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# bleach                        5.0.1
# branca                        0.6.0
# brotlipy                      0.7.0
# certifi                       2022.12.7
# cffi                          1.15.1
# charset-normalizer            2.1.1
# click                         8.1.3
# click-plugins                 1.1.1
# ...
